# %% [markdown]
# # Chatper 2 | `Variables and Simple Data Types`

# %%
# variables
message = "Hello Python World!"
print(message)

message = "Hello Python crash course world!"
print(message)
# Out:
# Hello Python World!
# Hello Python crash course world!

# %%
# changing case in a string with methods

name = "ada loverlance"
print(name.title())
# Out:
# Ada Loverlance

# %%
print(name.upper())
print(name.lower())
# Out:
# ADA LOVERLANCE
# ada loverlance

# %%
# concatinate

first_name =  "ada"
last_name = "Lovelance"

full_name = first_name + " " + last_name

print(full_name)
print("Hello, " + full_name.title() + "!")
# Out:
# ada Lovelance
# Hello, Ada Lovelance!

# %%
message = "Hello, " + full_name.title() + "!"
print(message)
# Out:
# Hello, Ada Lovelance!

# %%
# to add tab
print("Python")
print("\tPython")
# Out:
# Python
# 	Python

# %%
# to add new line
print("Python")
print("\nPython")
# Out:
# Python
#
# Python
