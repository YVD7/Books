# %%
from PIL import ImageColor
print(ImageColor.getcolor('red', 'RGBA')) # red color 
print(ImageColor.getcolor('RED', 'RGBA')) # RED color with upper case
print(ImageColor.getcolor('Black', 'RGBA')) # black color with Upper case first letter
print(ImageColor.getcolor('chocolate', 'RGBA')) # chocolate color 
print(ImageColor.getcolor('CornflowerBlue', 'RGBA')) # ConrflowerBlue
# Out:
# (255, 0, 0, 255)
# (255, 0, 0, 255)
# (0, 0, 0, 255)
# (210, 105, 30, 255)
# (100, 149, 237, 255)

# %%
from PIL import Image
catIm = Image.open("/home/yash/Downloads/29865801581_52dc75c9f4.jpg")
catIm
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=499x333>

# %%
catIm.size
# Out:
# (499, 333)

# %%
width, height = catIm.size

# %%
width
# Out:
# 499

# %%
height
# Out:
# 333

# %%
catIm.filename
# Out:
# '/home/yash/Downloads/29865801581_52dc75c9f4.jpg'

# %%
catIm.format
# Out:
# 'JPEG'

# %%
catIm.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
catIm.save('cat.jpeg')

# %%
from PIL import Image
im = Image.new('RGBA', (100, 200), 'purple')
im.save('purpleImg.png')
im2 = Image.new('RGBA', (20, 20))
im2.save('transperentImg.png')

# %%
from PIL import Image
catIm = Image.open('cat.jpeg')
croppedIm = catIm.crop((335, 345, 565, 560))
croppedIm.save('croppedImg.jpeg')
